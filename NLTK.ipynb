# %%
words = ["eating","eat","eaten","writing","write","written","give","giving","given"]

# %%
from nltk.stem import PorterStemmer
stemming=PorterStemmer()

# %%
for word in words:
    print(word + "-------->" + stemming.stem(word))
# Out:
# eating-------->eat
# eat-------->eat
# eaten-------->eaten
# writing-------->write
# write-------->write
# written-------->written
# give-------->give
# giving-------->give
# given-------->given

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|e$|s$|able$' , min=4)

# %%
reg_stemmer.stem('appreciable'),reg_stemmer.stem('eating'),reg_stemmer.stem('goes')
# Out:
# ('appreci', 'eat', 'goe')

# %%
from nltk.stem import SnowballStemmer
snowballstemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word + "------>" + snowballstemmer.stem(word))
# Out:
# eating------>eat
# eat------>eat
# eaten------>eaten
# writing------>write
# write------>write
# written------>written
# give------>give
# giving------>give
# given------>given
